# %% [markdown]
# # Lab 00: Environment Setup Verification
#
# **ING3513 - Introduction to Artificial Intelligence and Machine Learning**
#
# This notebook verifies that your Python environment is correctly set up with all required dependencies.

# %%
import pandas as pd

# Create a simple DataFrame
data = {
    'Course': ['ING3513'],
    'Topic': ['AI & Machine Learning'],
    'Status': ['Ready!']
}
df = pd.DataFrame(data)

print("Pandas version:", pd.__version__)
print("\nEnvironment check:")
print(df)
print("\n✓ Pandas is working correctly!")
